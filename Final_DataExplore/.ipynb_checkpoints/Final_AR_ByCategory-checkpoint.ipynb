# %%
import numpy as np                 
import pandas as pd 
import matplotlib.pyplot as plt     
import seaborn as sns 
import geopandas

# %%
crime = pd.read_csv('merge2.csv')

# %%
crime = crime[crime['Primary Type']!='LIQUOR LAW VIOLATION']
crime = crime[crime['Primary Type']!='ARSON']
crime = crime[crime['Primary Type']!='KIDNAPPING']
crime = crime[crime['Primary Type']!='STALKING']
crime = crime[crime['Primary Type']!='INTIMIDATION']
crime = crime[crime['Primary Type']!='OBSCENITY']
crime = crime[crime['Primary Type']!='HOMICIDE']
crime = crime[crime['Primary Type']!='PUBLIC INDECENCY']
crime = crime[crime['Primary Type']!='CONCEALED CARRY LICENSE VIOLATION']
crime = crime[crime['Primary Type']!='NON-CRIMINAL']
crime = crime[crime['Primary Type']!='OTHER NARCOTIC VIOLATION']
crime = crime[crime['Primary Type']!='NON - CRIMINAL']
crime = crime[crime['Primary Type']!='HUMAN TRAFFICKING']
crime = crime[crime['Primary Type']!='NON-CRIMINAL (SUBJECT SPECIFIED)']

# %% [markdown]
# # Arrest Rate by Crime Type

# %%
types = crime.groupby(by=['Primary Type']).agg({'Arrest':'sum','ID':'count'})
types['rate'] = types['Arrest']/types['ID']

# %%
types = types.sort_values('rate', ascending=False)

# %%
types.reset_index(inplace=True)

# %%
types.dtypes
# Out:
# Primary Type     object
# Arrest          float64
# ID                int64
# rate            float64
# dtype: object

# %%
#types.to_csv("FINAL_type_rate.csv")

# %%
types
# Out:
#                         Primary Type    Arrest      ID      rate
# 0                           GAMBLING    1846.0    1853  0.996222
# 1                       PROSTITUTION    6278.0    6311  0.994771
# 2                          NARCOTICS  108823.0  109714  0.991879
# 3   INTERFERENCE WITH PUBLIC OFFICER    4327.0    4575  0.945792
# 4                  WEAPONS VIOLATION    9941.0   12090  0.822250
# 5             PUBLIC PEACE VIOLATION    7923.0   10288  0.770121
# 6                  CRIMINAL TRESPASS   20174.0   27458  0.734722
# 7                        SEX OFFENSE     879.0    3205  0.274259
# 8                            ASSAULT   15943.0   63675  0.250381
# 9                            BATTERY   44593.0  187643  0.237648
# 10                     OTHER OFFENSE   12825.0   61262  0.209347
# 11        OFFENSE INVOLVING CHILDREN    1360.0    7590  0.179183
# 12                DECEPTIVE PRACTICE    7659.0   46558  0.164504
# 13               CRIM SEXUAL ASSAULT     575.0    4275  0.134503
# 14                             THEFT   26930.0  234716  0.114734
# 15                           ROBBERY    4190.0   39491  0.106100
# 16                   CRIMINAL DAMAGE    7626.0  108507  0.070281
# 17               MOTOR VEHICLE THEFT    2899.0   43785  0.066210
# 18                          BURGLARY    3537.0   61045  0.057941

# %%
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='CTA PLATFORM']
crime = crime[crime['Location Description']=='CHA PARKING LOT/GROUNDS']
crime = crime[crime['Location Description']=='DEPARTMENT STORE']
crime = crime[crime['Location Description']=='GROCERY FOOD STORE']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']
crime = crime[crime['Location Description']=='POLICE FACILITY/VEH PARKING LOT']


 'CTA GARAGE / OTHER PROPERTY',\
 'ABANDONED BUILDING',\
 'SIDEWALK',\
 'ALLEY',\
 'DRUG STORE',\
 'GAS STATION',\
 'CONVENIENCE STORE',\
 'PARK PROPERTY',\
 'VEHICLE NON-COMMERCIAL',\
 'VACANT LOT/LAND',\
 'SCHOOL, PUBLIC, BUILDING',\
 'SMALL RETAIL STORE',\
 'RESIDENCE PORCH/HALLWAY',\
 'HOTEL/MOTEL',\
 'CTA BUS STOP',\
 'SCHOOL, PUBLIC, GROUNDS',\
 'STREET',\
 'CHA APARTMENT',\
 'PARKING LOT/GARAGE(NON.RESID.)',\
 'RESIDENTIAL YARD (FRONT/BACK)',\
 'HOSPITAL BUILDING/GROUNDS',\
 'RESTAURANT',\
 'BAR OR TAVERN',\
 'APARTMENT',\
 'CTA BUS',\
 'OTHER',\
 'CTA TRAIN',\
 'BANK',\
 'RESIDENCE',\
 'COMMERCIAL / BUSINESS OFFICE',\
 'RESIDENCE-GARAGE']
# Out:
#   File "<ipython-input-68-a42ebf4eea27>", line 1
#     crime_loc=crime[crime['Location Description']='POLICE FACILITY/VEH PARKING LOT', 'CTA PLATFORM', 'CHA PARKING LOT/GROUNDS', 'DEPARTMENT STORE', 'GROCERY FOOD STORE', 'CTA GARAGE / OTHER PROPERTY', 'ABANDONED BUILDING', 'SIDEWALK', 'ALLEY', 'DRUG STORE', 'GAS STATION', 'CONVENIENCE STORE', 'PARK PROPERTY', 'VEHICLE NON-COMMERCIAL', 'VACANT LOT/LAND', 'SCHOOL, PUBLIC, BUILDING', 'SMALL RETAIL STORE', 'RESIDENCE PORCH/HALLWAY', 'HOTEL/MOTEL', 'CTA BUS STOP', 'SCHOOL, PUBLIC, GROUNDS', 'STREET', 'CHA APARTMENT', 'PARKING LOT/GARAGE(NON.RESID.)', 'RESIDENTIAL YARD (FRONT/BACK)', 'HOSPITAL BUILDING/GROUNDS', 'RESTAURANT', 'BAR OR TAVERN', 'APARTMENT', 'CTA BUS', 'OTHER', 'CTA TRAIN', 'BANK', 'RESIDENCE', 'COMMERCIAL / BUSINESS OFFICE', 'RESIDENCE-GARAGE']
#                                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Arrest Rate by Location Description

# %%
loc = crime.groupby(by=['Location Description']).agg({'Arrest':'sum','ID':'count'})
loc['rate'] = loc['Arrest']/loc['ID']
loc.sort_values('ID',ascending=False)
loc.to_csv('FINAL_loc_rate.csv')
# Out:
#                  Arrest     ID  Location Description      rate
# Community Area
# 25.0            27484.0  68356                 68356  0.402072
# 43.0             8673.0  35627                 35627  0.243439
# 23.0            14396.0  34412                 34412  0.418342
# 8.0              8535.0  34197                 34197  0.249583
# 29.0            12772.0  32536                 32536  0.392550
# 67.0             9609.0  29928                 29928  0.321071
# 71.0             8514.0  29476                 29476  0.288845
# 28.0             6867.0  29452                 29452  0.233159
# 24.0             4470.0  28206                 28206  0.158477
# 68.0             8445.0  27728                 27728  0.304566
# 49.0             8459.0  27704                 27704  0.305335
# 69.0             7865.0  26228                 26228  0.299870
# 32.0             7379.0  26110                 26110  0.282612
# 66.0             7877.0  25303                 25303  0.311307
# 44.0             6859.0  23414                 23414  0.292944
# 6.0              4305.0  22271                 22271  0.193301
# 26.0            11070.0  22270                 22270  0.497081
# 27.0             8472.0  20596                 20596  0.411342
# 61.0             6737.0  20165                 20165  0.334094
# 22.0             3601.0  19869                 19869  0.181237
# 46.0             5548.0  19838                 19838  0.279665
# 19.0             4894.0  19211                 19211  0.254750
# 30.0             4974.0  17468                 17468  0.284749
# 53.0             4925.0  16919                 16919  0.291093
# 42.0             5059.0  15991                 15991  0.316365
# 7.0              1803.0  15201                 15201  0.118611
# 1.0              4179.0  14671                 14671  0.284848
# 3.0              4703.0  14559                 14559  0.323030
# 15.0             2951.0  13065                 13065  0.225871
# 38.0             3514.0  12982                 12982  0.270682
# ...                 ...    ...                   ...       ...
# 76.0             1550.0   6686                  6686  0.231828
# 20.0             1707.0   6572                  6572  0.259738
# 60.0             1199.0   6537                  6537  0.183417
# 33.0             1348.0   6206                  6206  0.217209
# 17.0             1054.0   6073                  6073  0.173555
# 48.0             1025.0   5749                  5749  0.178292
# 5.0               857.0   5748                  5748  0.149095
# 45.0             1178.0   5649                  5649  0.208532
# 41.0              705.0   5632                  5632  0.125178
# 39.0              948.0   5501                  5501  0.172332
# 52.0             1317.0   5218                  5218  0.252396
# 54.0             1254.0   5003                  5003  0.250650
# 34.0             1045.0   4519                  4519  0.231246
# 10.0              712.0   4506                  4506  0.158012
# 11.0              874.0   4453                  4453  0.196272
# 59.0             1038.0   4163                  4163  0.249339
# 50.0             1202.0   4139                  4139  0.290408
# 62.0              768.0   4115                  4115  0.186634
# 57.0              787.0   3947                  3947  0.199392
# 64.0              687.0   3793                  3793  0.181123
# 37.0             1281.0   3606                  3606  0.355241
# 72.0              511.0   3598                  3598  0.142023
# 13.0              572.0   3270                  3270  0.174924
# 36.0              445.0   2394                  2394  0.185881
# 55.0              501.0   2313                  2313  0.216602
# 74.0              344.0   2238                  2238  0.153709
# 18.0              368.0   2210                  2210  0.166516
# 12.0              211.0   1698                  1698  0.124264
# 47.0              354.0   1574                  1574  0.224905
# 9.0               138.0    967                   967  0.142709
#
# [77 rows x 4 columns]

# %% [markdown]
# # Arrest Rate by Community Area

# %%
com = crime.groupby(by=['Community Area Name']).agg({'Arrest':'sum','ID':'count'})
com['rate'] = com['Arrest']/com['ID']

# %%
com = com.sort_values('rate')

# %%
com.to_csv("community_geo.csv")

# %% [markdown]
# # Arrest Rate by Police Beat

# %%
beat = crime.groupby(by=['Beat']).agg({'Arrest':'sum','ID':'count'})
beat['rate'] = beat['Arrest']/beat['ID']

# %%
beat = beat.sort_values('rate', ascending=False)

# %%
beat

# %%
beat['rate'].hist(figsize=(20,20))
plt.title('Arrest Rate Distributions by Police Beat')

# %% [markdown]
# # Police Beats: Highest and Lowest Arrest Rates
# #### Which types of crimes are most prevelant?

# %%
beat2131 = crime[crime['Beat']==2131]

# %%
beat1114 = crime[crime['Beat']==1115]

# %% [markdown]
# ### Beat 2131 Crimes by Count

# %%
beat2131.groupby(by=['Primary Type']).agg({'ID':'count'}).sort_values('ID', ascending=False)

# %% [markdown]
# ### Beat 1114 Crimes by Count

# %%
beat1114.groupby(by=['Primary Type']).agg({'ID':'count'}).sort_values('ID', ascending=False)

# %% [markdown]
# # Per Capita Income (Com Areas) / Arrest Rate

# %%
pci = crime.groupby(by=['PER CAPITA INCOME ']).agg({'Arrest':'sum','ID':'count'}).sort_values('PER CAPITA INCOME ')
pci['rate'] = pci['Arrest']/pci['ID']
pci.head()

# %%
pci.reset_index(inplace=True)
pci.head()

# %%
pci.to_csv("FINAL_pci.csv")

# %%
import statsmodels.formula.api as smf

pci.rename({"PER CAPITA INCOME ": "pci"}, axis = 'columns', inplace=True )

# %%
pci.columns

# %%
fig,ax=plt.subplots(figsize=(15,15))
sns.set_style("darkgrid")
ax = sns.scatterplot(x="rate", y="pci", s=100 ,data=pci)
ax.grid(True,axis='both',linewidth=2)
ax.set_xlabel('Arrest Rate',fontsize=30)
ax.set_ylabel('Per Capita Income',fontsize=30)

# %%
mod=smf.ols('rate ~ np.power(pci, 2) + pci ',pci).fit()
mod.summary()

# %%
corr=pci[['pci','rate']].corr()
corr.style.background_gradient()

# %%
hsi = crime.groupby(by=['HARDSHIP_INDEX']).agg({'Arrest':'sum','ID':'count'})
hsi['rate'] = hsi['Arrest']/hsi['ID']
hsi.head()

# %%
hsi.reset_index(inplace=True)

# %%
fig,ax=plt.subplots(figsize=(15,15))
ax = sns.scatterplot(x="rate", y="HARDSHIP_INDEX", s=100 ,data=hsi)
ax.grid(True,axis='both',linewidth=2)
ax.set_xlabel('Arrest Rate',fontsize=30)
ax.set_ylabel('HSI',fontsize=30)
