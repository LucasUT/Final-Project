# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
crime = pd.read_csv("data_crime_1217.csv")

# %%
socio = pd.read_excel("data_socio_CAs.xlsx")

# %%
crime.head()
# Out:
#    Unnamed: 0        ID Case Number          Date                Block IUCR  \
# 0         3.0  10508693    HZ250496  5/3/16 23:40   013XX S SAWYER AVE  486
# 1        89.0  10508695    HZ250409  5/3/16 21:40   061XX S DREXEL AVE  486
# 2       197.0  10508697    HZ250503  5/3/16 23:31  053XX W CHICAGO AVE  470
# 3       673.0  10508698    HZ250424  5/3/16 22:10    049XX W FULTON ST  460
# 4       911.0  10508699    HZ250455  5/3/16 22:00    003XX N LOTUS AVE  820
#
#              Primary Type              Description Location Description  \
# 0                 BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT
# 1                 BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE
# 2  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT               STREET
# 3                 BATTERY                   SIMPLE             SIDEWALK
# 4                   THEFT           $500 AND UNDER            RESIDENCE
#
#   Arrest              ...                Ward  Community Area  FBI Code  \
# ...

# %%
crime.columns
# Out:
# Index([u'Unnamed: 0', u'ID', u'Case Number', u'Date', u'Block', u'IUCR',
#        u'Primary Type', u'Description', u'Location Description', u'Arrest',
#        u'Domestic', u'Beat', u'District', u'Ward', u'Community Area',
#        u'FBI Code', u'X Coordinate', u'Y Coordinate', u'Year', u'Updated On',
#        u'Latitude', u'Longitude', u'Location'],
#       dtype='object')

# %%
#crime = crime[['ID', 'Date', 'Primary Type', 'Description', 'Location Description', 'Arrest', 'Domestic', 'Community Area', 'X Coordinate', 'Y Coordinate', 'Year', 'Latitude', 'Longitude', 'Location']]

# %%
crime.head()
# Out:
#    Unnamed: 0        ID Case Number          Date                Block IUCR  \
# 0         3.0  10508693    HZ250496  5/3/16 23:40   013XX S SAWYER AVE  486
# 1        89.0  10508695    HZ250409  5/3/16 21:40   061XX S DREXEL AVE  486
# 2       197.0  10508697    HZ250503  5/3/16 23:31  053XX W CHICAGO AVE  470
# 3       673.0  10508698    HZ250424  5/3/16 22:10    049XX W FULTON ST  460
# 4       911.0  10508699    HZ250455  5/3/16 22:00    003XX N LOTUS AVE  820
#
#              Primary Type              Description Location Description  \
# 0                 BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT
# 1                 BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE
# 2  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT               STREET
# 3                 BATTERY                   SIMPLE             SIDEWALK
# 4                   THEFT           $500 AND UNDER            RESIDENCE
#
#   Arrest              ...                Ward  Community Area  FBI Code  \
# ...

# %%
crime.shape
# Out:
# (1048576, 23)

# %%
crime.dropna(inplace=True)

# %%
crime.shape
# Out:
# (1039230, 23)

# %%
#crime['Community Area'].astype(int)

# %%
#crime['Community Area'] = crime['Community Area'].astype(int)
#crime.head(1)

# %%
socio['Community Number'] = socio['Community Number'].astype(float)

# %%
socio.columns
# Out:
# Index([u'Community Number', u'Community Area Name', u'TOT_POP', u'MED_AGE',
#        u'UND19', u'A20_34', u'A35_49', u'WHITE', u'HISP', u'BLACK', u'ASIAN',
#        u'OTHER', u'POP_16OV', u'IN_LBFRC', u'EMP', u'UNEMP', u'NOT_IN_LBFRC',
#        u'POP_25OV', u'LT_HS', u'HS', u'SOME_COLL', u'ASSOC', u'BACH',
#        u'GRAD_PROF', u'INC_LT_25K', u'INC_25_50K', u'INC_50_75K',
#        u'INC_75_100K', u'INC_100_150K', u'INC_GT_150', u'MEDINC', u'TOT_HH',
#        u'VAC_HU', u'FAM_HH', u'SP_WCHILD_HH', u'NONFAM_HH', u'Per_HH_Crowded',
#        u'Per_HH_BelowPov', u'PER CAPITA INCOME ', u'HARDSHIP_INDEX',
#        u'Birth Rate', u'General Fertility Rate', u'Teen Birth Rate',
#        u'Preterm Births', u'Infant Mortality Rate', u'Mort_homicide',
#        u'Mort_diabetes', u'Mort_Firearm', u'Life_Exp_10'],
#       dtype='object')

# %%
#socio.drop(columns=['ASSAULT', 'BATTERY', 'HOMICIDE', 'THEFT', 'ROBBERY', 'BURGLARY',
#       'MOTOR VEHICLE THEFT', 'NARCOTICS', 'CRIMINAL TRESPASS',
#       'WEAPONS VIOLATION', 'CRIMINAL DAMAGE', 'PROSTITUTION', 'SEX OFFENSE',
#       'CRIM SEXUAL ASSAULT', 'PUBLIC PEACE VIOLATION',
#       'OFFENSE INVOLVING CHILDREN', 'INTERFERENCE WITH PUBLIC OFFICER',
#       'OBSCENITY', 'STALKING', 'KIDNAPPING', 'ARSON', 'INTIMIDATION',
#       'GAMBLING'], inplace=True)
socio.head(1)
# Out:
#    Community Number Community Area Name  TOT_POP  MED_AGE  UND19  A20_34  \
# 0              14.0         Albany Park    51575     33.6  13354   13738
#
#    A35_49  WHITE   HISP  BLACK     ...       HARDSHIP_INDEX  Birth Rate  \
# 0   11975  14932  24892   2337     ...                   53        18.3
#
#    General Fertility Rate  Teen Birth Rate  Preterm Births  \
# 0                    76.5             44.5             8.3
#
#    Infant Mortality Rate  Mort_homicide  Mort_diabetes  Mort_Firearm  \
# 0                    4.9            4.7           72.1           5.3
#
#    Life_Exp_10
# 0         80.6
#
# [1 rows x 49 columns]

# %%
crime.head()
# Out:
#    Unnamed: 0        ID Case Number          Date                Block IUCR  \
# 0         3.0  10508693    HZ250496  5/3/16 23:40   013XX S SAWYER AVE  486
# 1        89.0  10508695    HZ250409  5/3/16 21:40   061XX S DREXEL AVE  486
# 2       197.0  10508697    HZ250503  5/3/16 23:31  053XX W CHICAGO AVE  470
# 3       673.0  10508698    HZ250424  5/3/16 22:10    049XX W FULTON ST  460
# 4       911.0  10508699    HZ250455  5/3/16 22:00    003XX N LOTUS AVE  820
#
#              Primary Type              Description Location Description  \
# 0                 BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT
# 1                 BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE
# 2  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT               STREET
# 3                 BATTERY                   SIMPLE             SIDEWALK
# 4                   THEFT           $500 AND UNDER            RESIDENCE
#
#   Arrest              ...                Ward  Community Area  FBI Code  \
# ...

# %%
socio.head()
# Out:
#    Community Number Community Area Name  TOT_POP  MED_AGE  UND19  A20_34  \
# 0              14.0         Albany Park    51575     33.6  13354   13738
# 1              57.0      Archer Heights    13233     33.0   4016    2933
# 2              34.0       Armour Square    13699     42.0   2997    2824
# 3              70.0             Ashburn    43283     35.5  12983    8368
# 4              71.0      Auburn Gresham    45770     39.6  11432    9224
#
#    A35_49  WHITE   HISP  BLACK     ...       HARDSHIP_INDEX  Birth Rate  \
# 0   11975  14932  24892   2337     ...                   53        18.3
# 1    2879   2477  10178     79     ...                   67        18.1
# 2    2539   1599    423   1248     ...                   82        11.5
# 3    8998   5044  16374  20721     ...                   37        14.7
# 4    7941    257    614  44267     ...                   74        15.1
#
#    General Fertility Rate  Teen Birth Rate  Preterm Births  \
# ...

# %%
crime.head(1)
# Out:
#    Unnamed: 0        ID Case Number          Date               Block IUCR  \
# 0         3.0  10508693    HZ250496  5/3/16 23:40  013XX S SAWYER AVE  486
#
#   Primary Type              Description Location Description Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   True
#
#                ...                Ward  Community Area  FBI Code  \
# 0              ...                24.0            29.0       08B
#
#    X Coordinate  Y Coordinate    Year     Updated On   Latitude  Longitude  \
# 0     1154907.0     1893681.0  2016.0  5/10/16 15:56  41.864073 -87.706819
#
#                         Location
# 0  (41.864073157, -87.706818608)
#
# [1 rows x 23 columns]

# %%
socio.rename(columns={"Community Number": "Community Area"}, inplace=True)
socio.head(1)
# Out:
#    Community Area Community Area Name  TOT_POP  MED_AGE  UND19  A20_34  \
# 0            14.0         Albany Park    51575     33.6  13354   13738
#
#    A35_49  WHITE   HISP  BLACK     ...       HARDSHIP_INDEX  Birth Rate  \
# 0   11975  14932  24892   2337     ...                   53        18.3
#
#    General Fertility Rate  Teen Birth Rate  Preterm Births  \
# 0                    76.5             44.5             8.3
#
#    Infant Mortality Rate  Mort_homicide  Mort_diabetes  Mort_Firearm  \
# 0                    4.9            4.7           72.1           5.3
#
#    Life_Exp_10
# 0         80.6
#
# [1 rows x 49 columns]

# %%
merge = pd.merge(crime, socio, on="Community Area", how="inner")

# %%
merge.head(3)
# Out:
#    Unnamed: 0        ID Case Number           Date                   Block  \
# 0         3.0  10508693    HZ250496   5/3/16 23:40      013XX S SAWYER AVE
# 1     48110.0  10448396    HZ187600  3/14/16 10:15    019XX S TRUMBULL AVE
# 2     52366.0  10495378    HZ235779  4/22/16 11:21  015XX S CHRISTIANA AVE
#
#    IUCR       Primary Type               Description Location Description  \
# 0   486            BATTERY   DOMESTIC BATTERY SIMPLE            APARTMENT
# 1   610           BURGLARY            FORCIBLE ENTRY            APARTMENT
# 2  143A  WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN      VACANT LOT/LAND
#
#   Arrest     ...     HARDSHIP_INDEX  Birth Rate  General Fertility Rate  \
# 0   True     ...                 87        20.6                    86.3
# 1  False     ...                 87        20.6                    86.3
# 2   True     ...                 87        20.6                    86.3
#
#    Teen Birth Rate  Preterm Births Infant Mortality Rate  Mort_homicide  \
# ...

# %%
merge.shape
# Out:
# (1039229, 71)

# %%
merge['ID'].nunique()
# Out:
# 1039229

# %%
merge.columns
# Out:
# Index([            u'Unnamed: 0',                     u'ID',
#                   u'Case Number',                   u'Date',
#                         u'Block',                   u'IUCR',
#                  u'Primary Type',            u'Description',
#          u'Location Description',                 u'Arrest',
#                      u'Domestic',                   u'Beat',
#                      u'District',                   u'Ward',
#                u'Community Area',               u'FBI Code',
#                  u'X Coordinate',           u'Y Coordinate',
#                          u'Year',             u'Updated On',
#                      u'Latitude',              u'Longitude',
#                      u'Location',    u'Community Area Name',
#                       u'TOT_POP',                u'MED_AGE',
#                         u'UND19',                 u'A20_34',
#                        u'A35_49',                  u'WHITE',
# ...

# %%
merge['Date'].head()
# Out:
# 0     5/3/16 23:40
# 1    3/14/16 10:15
# 2    4/22/16 11:21
# 3      5/1/13 1:26
# 4      5/4/16 2:08
# Name: Date, dtype: object

# %%
merge['Date'] = merge['Date'].astype(str)

# %%
date = pd.DataFrame(merge.Date.str.split('/',2).tolist(),
                                   columns = ['month','day','year'])
date.head(1)
# Out:
#   month day      year
# 0     5   3  16 23:40

# %%
time = pd.DataFrame(date.year.str.split(" ",1).tolist(),
                                   columns = ['year_','time'])
time.head(1)
# Out:
#   year_   time
# 0    16  23:40

# %%
date.drop(['year'], axis=1, inplace=True)
#date.head(1)

# %%
#time.rename(columns={"year": "day"}, inplace=True)

# %%
datetime = pd.concat([date,time], axis = 1)

# %%
datetime.head(1)
# Out:
#   month day year_   time
# 0     5   3    16  23:40

# %%
datetime.rename(columns={"year_": "year"}, inplace=True)

# %%
datetime.head(1)
# Out:
#   month day year   time
# 0     5   3   16  23:40

# %%
merge = pd.concat([merge,datetime],axis=1)

# %%
merge.drop(['Date'],axis=1,inplace=True)

# %%
merge.head()
# Out:
#    Unnamed: 0        ID Case Number                   Block  IUCR  \
# 0         3.0  10508693    HZ250496      013XX S SAWYER AVE   486
# 1     48110.0  10448396    HZ187600    019XX S TRUMBULL AVE   610
# 2     52366.0  10495378    HZ235779  015XX S CHRISTIANA AVE  143A
# 3     57943.0     20859    HW254987       019XX S DRAKE AVE   110
# 4     63024.0  10508736    HZ250568     035XX W GRENSHAW ST  051A
#
#         Primary Type               Description Location Description Arrest  \
# 0            BATTERY   DOMESTIC BATTERY SIMPLE            APARTMENT   True
# 1           BURGLARY            FORCIBLE ENTRY            APARTMENT  False
# 2  WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN      VACANT LOT/LAND   True
# 3           HOMICIDE       FIRST DEGREE MURDER                ALLEY   True
# 4            ASSAULT       AGGRAVATED: HANDGUN            APARTMENT   True
#
#   Domestic  ...    Preterm Births  Infant Mortality Rate  Mort_homicide  \
# ...

# %%
merge['year'].unique()
# Out:
# array(['16', '13', '15', '14', '12'], dtype=object)

# %%
merge['Community Area'].nunique()
# Out:
# 77

# %%
merge['ID'].nunique()
# Out:
# 1039229

# %%
merge.dropna(inplace=True)
merge.shape
# Out:
# (1039229, 74)

# %%
#merge.to_csv("final_merged_data.csv")

# %%
crime = merge
crime.shape
# Out:
# (1039229, 74)

# %%
crime['Arrest'] = crime['Arrest'].replace({False: 0, True: 1})
crime['Beat']=crime['Beat'].astype(str)
crime['Ward']=crime['Ward'].astype(str)
crime['District']=crime['District'].astype(str)
crime['Community Area']=crime['Community Area'].astype(str)

# %%
crime['time'].head()
# Out:
# 0    23:40
# 1    10:15
# 2    11:21
# 3     1:26
# 4     2:08
# Name: time, dtype: object

# %%
time = pd.DataFrame(crime.time.str.split(":",1).tolist(),
                                   columns = ['hour','minute'])
time.drop(columns=['minute'], inplace=True)
time['hour']=time['hour'].astype(str)
time.head(1)
# Out:
#   hour
# 0   23

# %%
crime['hour']=time['hour'].values
crime.shape
# Out:
# (1039229, 75)

# %%
crime = crime[crime['Primary Type']!='LIQUOR LAW VIOLATION']
crime = crime[crime['Primary Type']!='ARSON']
crime = crime[crime['Primary Type']!='KIDNAPPING']
crime = crime[crime['Primary Type']!='STALKING']
crime = crime[crime['Primary Type']!='INTIMIDATION']
crime = crime[crime['Primary Type']!='OBSCENITY']
crime = crime[crime['Primary Type']!='HOMICIDE']
crime = crime[crime['Primary Type']!='PUBLIC INDECENCY']
crime = crime[crime['Primary Type']!='CONCEALED CARRY LICENSE VIOLATION']
crime = crime[crime['Primary Type']!='NON-CRIMINAL']
crime = crime[crime['Primary Type']!='OTHER NARCOTIC VIOLATION']
crime = crime[crime['Primary Type']!='NON - CRIMINAL']
crime = crime[crime['Primary Type']!='HUMAN TRAFFICKING']
crime = crime[crime['Primary Type']!='NON-CRIMINAL (SUBJECT SPECIFIED)']

# %%
crime['Primary Type'].unique()
# Out:
# array(['BATTERY', 'BURGLARY', 'WEAPONS VIOLATION', 'ASSAULT',
#        'PUBLIC PEACE VIOLATION', 'NARCOTICS', 'OTHER OFFENSE', 'THEFT',
#        'ROBBERY', 'CRIMINAL DAMAGE', 'MOTOR VEHICLE THEFT',
#        'DECEPTIVE PRACTICE', 'CRIMINAL TRESPASS', 'CRIM SEXUAL ASSAULT',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'SEX OFFENSE',
#        'OFFENSE INVOLVING CHILDREN', 'PROSTITUTION', 'GAMBLING'],
#       dtype=object)

# %% [markdown]
# ## STOP: Need to add time from Times.ipynb

# %%
crime['hour']=time['hour'].astype(int)
bins = [0, 5, 10, 18, 24]
names = ['Early_AM', 'Morning', 'Day','Night']

crime['hour'] = pd.cut(crime['hour'], bins, labels=names)

# %%
crime['hour'].head()
# Out:
# 0       Night
# 1     Morning
# 2         Day
# 4    Early_AM
# 5     Morning
# Name: hour, dtype: category
# Categories (4, object): [Early_AM < Morning < Day < Night]

# %%
crime.to_csv('final_working_data.csv')
